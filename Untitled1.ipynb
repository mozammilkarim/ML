# %%
import pandas as pd


wineNames=['Alcohol' , 'Malic acid', 'Ash' , 'Alcalinity of ash','Magnesium',  'Total phenols', 'Flavanoids' ,' Nonflavanoid phenols' , 'Proanthocyanins' ,'Color intensity','Hue','OD280/OD315 of diluted wines' ,'Proline']
wineData=pd.read_csv('./wineData.csv',index_col=False,names=wineNames)
wineData.columns
wineData.describe()
wineData.info()
wineData
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Alcohol                       178 non-null    int64
#  1   Malic acid                    178 non-null    float64
#  2   Ash                           178 non-null    float64
#  3   Alcalinity of ash             178 non-null    float64
#  4   Magnesium                     178 non-null    float64
#  5   Total phenols                 178 non-null    int64
#  6   Flavanoids                    178 non-null    float64
#  7    Nonflavanoid phenols         178 non-null    float64
#  8   Proanthocyanins               178 non-null    float64
#  9   Color intensity               178 non-null    float64
#  10  Hue                           178 non-null    float64
#  11  OD280/OD315 of diluted wines  178 non-null    float64
# ...

# %% [markdown]
# no missing values and all are continous variables

# %%
wineData.Alcohol.value_counts()
# all quality of wines is in good range
# Out:
# 2    71
# 1    59
# 3    48
# Name: Alcohol, dtype: int64

# %%
wineData.corr()
# Out:
#                                Alcohol  Malic acid       Ash  \
# Alcohol                       1.000000   -0.328222  0.437776
# Malic acid                   -0.328222    1.000000  0.094397
# Ash                           0.437776    0.094397  1.000000
# Alcalinity of ash            -0.049643    0.211545  0.164045
# Magnesium                     0.517859   -0.310235  0.288500
# Total phenols                -0.209179    0.270798 -0.054575
# Flavanoids                   -0.719163    0.289101 -0.335167
#  Nonflavanoid phenols        -0.847498    0.236815 -0.411007
# Proanthocyanins               0.489109   -0.155929  0.292977
# Color intensity              -0.499130    0.136698 -0.220746
# Hue                           0.265668    0.546364  0.248985
# OD280/OD315 of diluted wines -0.617369   -0.071747 -0.561296
# Proline                      -0.788230    0.072343 -0.368710
#
#                               Alcalinity of ash  Magnesium  Total phenols  \
# ...

# %% [markdown]
# proline, OD280 of wines ,
# flavanoids and nonflavanoids are
# are strongly negatively corelated with
# quality of wine

# %%
from pandas.plotting import scatter_matrix
attributes=['Proline','OD280/OD315 of diluted wines','Flavanoids','Alcohol']
# scatter_matrix(wineData[attributes],figsize=(12,8))

# %%
# separating features and label column
newfeatures=['Proline','Magnesium','OD280/OD315 of diluted wines','Ash','Color intensity','Proanthocyanins','Malic acid','Flavanoids']
reducedX=wineData[newfeatures]

y=wineData['Alcohol']
from sklearn.model_selection import train_test_split
trainX,valX,trainY,valY=train_test_split(reducedX,y,test_size=0.2,random_state=0)

# %%
#now scaling up the features
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
trainX=sc.fit_transform(trainX)
valX=sc.transform(valX)

# %%
# reducedX
# y
# from sklearn import tree
# clf = tree.DecisionTreeClassifier()
# clf = clf.fit(trainX,trainY)
# prediction=clf.predict(valX)
#using logistic regression
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf = clf.fit(trainX,trainY)
prediction=clf.predict(valX)
#using random forest
# from sklearn.ensemble import RandomForestClassifier
# clf = RandomForestClassifier(n_estimators=200)
# clf = clf.fit(trainX,trainY)
# prediction=clf.predict(valX)

# %%
# prediction

# %%
# from sklearn import sklearn.metrics.accuracy_score as metrics
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(valY,prediction)
# confusion_matrix(valY,prediction)
# Out:
# 0.9166666666666666

# %% [markdown]
# accuracy can't be much greater than 94.44% using decision tree and random forest classifiers
